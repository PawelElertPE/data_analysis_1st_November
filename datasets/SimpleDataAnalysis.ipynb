# %% [markdown]
# ## Data Loading and Analysis

# %% [markdown]
# - Show the datasets/ folder under the current working directory
# - Show the CSV file under there
# - Should uninstall pandas, requests, seaborn

# %% [raw]
# ### ChatGPT
#
# I have a CSV file with data on my local machine. What is the best way to load and analyze this data in Python?
#
# - This will suggest Pandas, look at the basic code there

# %%
import pandas as pd

# %% [markdown]
# Now if this does not work, if it gives you an error

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
insurance_data = pd.read_csv('datasets/insurance.csv')

insurance_data
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33   other  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [raw]
# ### ChatGPT
#
# I have data in a dataframe, could you please make some suggestions on how I could explore this data using pandas?

# %%
insurance_data.head(10)
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33   other  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60   other  25.840         0     no  northwest  28923.13692

# %%
insurance_data.tail(10)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [raw]
# ### ChatGPT
#
# # I have a DataFrame with insurance data with the following columns age, gender, bmi, children, smoker, region, and charges
# # How do I filter and store separate only those records where age > 45?

# %%
filtered_data = insurance_data[insurance_data['age'] > 45]

filtered_data.head()
# Out:
#     age  gender    bmi  children smoker     region      charges
# 6    46  female  33.44         1     no  southeast   8240.58960
# 9    60   other  25.84         0     no  northwest  28923.13692
# 11   62  female  26.29         0    yes  southeast  27808.72510
# 13   56  female  39.82         0     no  southeast  11090.71780
# 16   52  female  30.78         1     no  northeast  10797.33620

# %% [raw]
# ### ChatGPT
#
# Using the same data how do I filter and access those records where age > 45 and the person smokes?

# %%
filtered_data = insurance_data[(insurance_data['age'] > 45) & (insurance_data['smoker'] == 'yes')]

filtered_data.head()
# Out:
#     age  gender     bmi  children smoker     region      charges
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 39   60    male  39.900         0    yes  southwest  48173.36100
# 52   48    male  28.000         1    yes  southwest  23568.27200
# 55   58    male  36.955         2    yes  northwest  47496.49445
# 58   53  female  22.880         1    yes  southeast  23244.79020

# %% [raw]
# ### ChatGPT
#
# Using the same data how do I filter and access those records where bmi > 30 or the person smokes?

# %%
filtered_data = insurance_data[(insurance_data['bmi'] > 30) | (insurance_data['smoker'] == 'yes')]

filtered_data.head()
# Out:
#     age  gender    bmi  children smoker     region     charges
# 0    19  female  27.90         0    yes  southwest  16884.9240
# 1    18    male  33.77         1     no  southeast   1725.5523
# 2    28    male  33.00         3     no  southeast   4449.4620
# 6    46  female  33.44         1     no  southeast   8240.5896
# 11   62  female  26.29         0    yes  southeast  27808.7251

# %% [raw]
# ### ChatGPT
#
# How do I trim the dataset so the children columns is not included?

# %%
trimmed_data = insurance_data.drop(columns=['children'])

trimmed_data.head()
# Out:
#    age  gender     bmi smoker     region      charges
# 0   19  female  27.900    yes  southwest  16884.92400
# 1   18    male  33.770     no  southeast   1725.55230
# 2   28    male  33.000     no  southeast   4449.46200
# 3   33   other  22.705     no  northwest  21984.47061
# 4   32    male  28.880     no  northwest   3866.85520

# %% [raw]
# ### ChatGPT
#
# Is there a way I can compute the average charges for smokers and non-smokers?

# %%
average_charges_smokers = insurance_data[insurance_data['smoker'] == 'yes']['charges'].mean()

average_charges_non_smokers = insurance_data[insurance_data['smoker'] == 'no']['charges'].mean()

# %%
print(f'Average charges for smokers: {average_charges_smokers:.2f}')
print(f'Average charges for non-smokers: {average_charges_non_smokers:.2f}')
# Out:
# Average charges for smokers: 32050.23
# Average charges for non-smokers: 8434.27

# %% [raw]
# ### ChatGPT
#
# How can I visualize the relationship between bmi and insurance charges?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.scatter(insurance_data['bmi'], insurance_data['charges'], alpha=0.5)
plt.title('BMI vs. Insurance Charges')
plt.xlabel('BMI')
plt.ylabel('Insurance Charges')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Create a box plot
sns.boxplot(x='smoker', y='charges', data=insurance_data)
plt.title('Insurance Charges by Smoking Status (Box Plot)')
plt.xlabel('Smoker')
plt.ylabel('Insurance Charges')
plt.show()
